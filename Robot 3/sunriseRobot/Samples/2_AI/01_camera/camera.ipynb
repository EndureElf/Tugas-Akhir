# %% [markdown]
# <center><img src="../logo.png" alt="Header" style="width: 800px;"/></center>

# %%
import cv2
import ipywidgets.widgets as widgets
import time

# %%
from SunriseRobotLib import Mipi_Camera
# 打印Mipi_Camera库的函数 Print the Mipi_Camera library function
help(Mipi_Camera)
# Out:
# Help on class Mipi_Camera in module SunriseRobotLib.mipi_camera:
#
# class Mipi_Camera(builtins.object)
#  |  Mipi_Camera(width=1920, height=1080, debug=False)
#  |
#  |  Methods defined here:
#  |
#  |  __del__(self)
#  |
#  |  __init__(self, width=1920, height=1080, debug=False)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_frame(self)
#  |      # 获取摄像头的一帧图片
#  |
#  |  get_frame_jpg(self, text='', color=(0, 255, 0))
#  |      # 获取摄像头的jpg图片
#  |
#  |  isOpened(self)
#  |      # 摄像头是否打开成功
#  |
#  |  read(self)
#  |      # 获取摄像头的一帧图片
#  |
#  |  release(self)
#  |      # 释放摄像头设备总线
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  DEFAULT_FPS = 30
#  |
#  |  DEFAULT_HEIGHT = 1080
#  |
#  |  DEFAULT_WIDTH = 1920

# %%
width=640
height=480
g_camera = Mipi_Camera(width, height, debug=True)

if g_camera.isOpened():
    print("Open Camera OK")
else:
    print("Fail To Open Camera")

# %%
#bgr8转jpeg格式
def bgr8_to_jpeg(value, quality=75):
    return bytes(cv2.imencode('.jpg', value)[1])

image_widget = widgets.Image(format='jpeg', width=320, height=240)

# %%
display(image_widget)

try:
    m_fps = 0
    t_start = time.time()
    while g_camera.isOpened():
        
        ret, frame = g_camera.read()
        if not ret:
            print("Camera Read Fail")
            break

        m_fps = m_fps + 1
        fps = m_fps / (time.time() - t_start)
        if (time.time() - t_start) >= 2:
            m_fps = fps
            t_start = time.time() - 1

        text="FPS:" + str(int(fps))
        cv2.putText(frame, text, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)
        image_widget.value = bgr8_to_jpeg(frame)

except Exception as e:
    print("Exception:", e)
except KeyboardInterrupt:
    print("KeyboardInterrupt")
    pass
except:
    print("Unknow error")

# %%
# 释放摄像头 release camera
g_camera.release()
